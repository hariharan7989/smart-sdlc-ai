# %%
from transformers import pipeline
import os

# Use your own Hugging Face token
API_KEY = "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"
os.environ["HUGGINGFACEHUB_API_TOKEN"] = API_KEY

# Use a lightweight conversational model
chatbot = pipeline("text-generation", model="microsoft/DialoGPT-medium")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/863M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def ask_sdlc_bot(user_input):
    prompt = f"You are a helpful assistant guiding through SDLC. Question: {user_input}"
    response = chatbot(prompt, max_length=150, do_sample=True, top_k=50)[0]['generated_text']
    return response.split("Question:")[-1].strip()

# %%
def generate_document(doc_type, project_name):
    if doc_type.lower() == "srs":
        return f"SRS for {project_name}:\n\n1. Introduction...\n2. Functional Requirements...\n3. Non-functional..."
    elif doc_type.lower() == "test plan":
        return f"Test Plan for {project_name}:\n\n1. Test Objectives...\n2. Test Scenarios...\n3. Pass/Fail criteria..."
    else:
        return "Please choose between SRS or Test Plan."

# %%
while True:
    print("\nOptions: explain | suggest | generate | ask | exit")
    action = input("Your choice: ").lower()

    if action == "explain":
        phase = input("Enter SDLC phase: ")
        print(ask_sdlc_bot(f"Explain the {phase} phase in SDLC"))

    elif action == "suggest":
        phase = input("Enter SDLC phase for suggestions: ")
        print(ask_sdlc_bot(f"Suggest best tools and practices for {phase} phase"))

    elif action == "generate":
        doc = input("Document type (SRS/Test Plan): ")
        name = input("Project name: ")
        print(generate_document(doc, name))

    elif action == "ask":
        q = input("Your question: ")
        print(ask_sdlc_bot(q))

    elif action == "exit":
        print("Goodbye!")
        break
# Out:
# Options: explain | suggest | generate | ask | exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7a0d9ca59196> in <cell line: 0>()
#       1 while True:
#       2     print("\nOptions: explain | suggest | generate | ask | exit")
# ----> 3     action = input("Your choice: ").lower()
#       4
#       5     if action == "explain":
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Install necessary libraries
# !pip install transformers --quiet
# !pip install huggingface_hub --quiet

from transformers import pipeline
import os

# ✅ Set Hugging Face API Key (your provided key)
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# ✅ Load chatbot model from Hugging Face
chatbot = pipeline("text-generation", model="microsoft/DialoGPT-medium")

# ✅ Function to ask the chatbot
def ask_sdlc_bot(user_input):
    prompt = f"You are a smart chatbot helping with SDLC. Question: {user_input}"
    response = chatbot(prompt, max_length=200, do_sample=True, top_k=50)[0]['generated_text']
    return response.split("Question:")[-1].strip()

# ✅ Document Generator (SRS, Test Plan)
def generate_document(doc_type, project_name):
    if doc_type.lower() == "srs":
        return f"""
📄 SRS Document for {project_name}

1. Introduction
2. Overall Description
3. Functional Requirements
4. Non-Functional Requirements
5. External Interface Requirements
"""
    elif doc_type.lower() == "test plan":
        return f"""
🧪 Test Plan for {project_name}

1. Test Objectives
2. Test Strategy
3. Test Cases
4. Pass/Fail Criteria
"""
    else:
        return "⚠️ Please enter either 'SRS' or 'Test Plan'."

# ✅ Chat Interface
print("👋 Welcome to Smart SDLC Chat Assistant!")
print("Options: explain | suggest | generate | ask | exit")

while True:
    action = input("\n👉 What would you like to do? ").lower()

    if action == "explain":
        phase = input("🌀 Enter SDLC phase: ")
        print("💬", ask_sdlc_bot(f"Explain the {phase} phase in SDLC"))

    elif action == "suggest":
        phase = input("🔍 Enter SDLC phase for suggestions: ")
        print("💡", ask_sdlc_bot(f"Suggest tools and best practices for {phase} phase"))

    elif action == "generate":
        doc = input("📂 Enter document type (SRS/Test Plan): ")
        name = input("📌 Enter project name: ")
        print(generate_document(doc, name))

    elif action == "ask":
        q = input("💭 Ask your SDLC-related question: ")
        print("🤖", ask_sdlc_bot(q))

    elif action == "exit":
        print("👋 Exiting Smart SDLC Chat Assistant. Thank you!")
        break

    else:
        print("⚠️ Invalid option. Please choose again.")
# Out:
# Device set to use cuda:0
# 👋 Welcome to Smart SDLC Chat Assistant!
# Options: explain | suggest | generate | ask | exit
#
# 👉 What would you like to do? a project
# ⚠️ Invalid option. Please choose again.
#
# 👉 What would you like to do? generate
# 📂 Enter document type (SRS/Test Plan): test plan
# 📌 Enter project name: Health AI
#
# 🧪 Test Plan for Health AI
#
# 1. Test Objectives
# 2. Test Strategy
# 3. Test Cases
# 4. Pass/Fail Criteria
#
#
# 👉 What would you like to do? explain
# 🌀 Enter SDLC phase: design
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
